# %%
import pandas as pd
#working on integrating this information with mtgjson, but until that feature works, we don't need this.
#import utility

# %%
#path to our data, feel free to change this to whatever dataset you want.
buylistPath = 'Buylist.csv'
pricingPath = 'Pricing.csv'

#Fees for buying and selling. Loosely based on TCGplayer numbers.
#Will be a little more for cheaper cards, and a little less for more expensive cards
sellFee = .12
buyFee = .10

#for the simple math we've got set up, this makes it easier down below.
sellCut = 1 - sellFee
buyCut = 1 - buyFee

#If I can't buy a cheeseburger with something, it doesn't actually have value.
cheeseburger = 5

# %%
buylistData = pd.read_csv(buylistPath)
pricingData = pd.read_csv(pricingPath)

# %%
#make some dataframes that are smaller, so that we can run equivalencies on them, because sometimes the data is bad.
buylist = buylistData[['TCGplayer Id','Set Name', 'Product Name']]
pricelist = pricingData[['TCGplayer Id','Set Name', 'Product Name']]

#checking if our data is clean.
#validates that tcgplayer id correlates to the same Set and Product Name
pricelist = pricelist.sort_values('TCGplayer Id')
pricelist = pricelist.reset_index(drop=True)

buylist = buylist.sort_values('TCGplayer Id')
buylist = buylist.reset_index(drop=True)

pricelist.compare(buylist)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#we know that our small data is clean, so now we can do the same to the big data.
pricelist = pricingData.sort_values('TCGplayer Id')
pricelist = pricelist.reset_index(drop=True)

buylist = buylistData.sort_values('TCGplayer Id')
buylist = buylist.reset_index(drop=True)

# %%
#getting the columns to use as our key values for the merge
#if we don't do this, we get a bunch of columns we have to remove.
#I don't know why pandas supports difference, but not unions on these things.
set1 = set(pricelist.columns.to_list())
set2 = set(buylist.columns.to_list())

keys = list(set1.intersection(set2))

result = pd.merge(pricelist, buylist, on=keys, how='outer')

# %%
#drop the utility columns that we don't care about.
result = result.drop(['Title', 'Add to Quantity', 'TCG Marketplace Price', 'My Store Reserve Quantity', 'My Store Price', 'Photo URL', 
'Total Quantity', 'Add to Quantity', 'TCG Marketplace Price', 'My Store Reserve Quantity', 'My Store Price', 'Buylist Quantity', 
'Add to Buylist Quantity', 'My Buylist Price', 'Pending Purchase Quantity', 'Number'], axis = 1)

# %%
#naively, we can now compare buylist market/high to tcg market/low, and get cards that make money.
#we'll do this only on things that have values for all of that.
#TODO: change this to filters in case the number of tables changes
filtered = result.dropna(thresh=12).copy()

# %%
filtered.head()
# Out:
#     TCGplayer Id Product Line           Set Name    Product Name Rarity  \
# 15        363363        Magic  Portal Second Age       Archangel      R
# 16        363364        Magic  Portal Second Age      Armageddon      R
# 29        363377        Magic  Portal Second Age  Coastal Wizard      R
# 54        363402        Magic  Portal Second Age     Goblin Lore      U
# 55        363403        Magic  Portal Second Age   Goblin Matron      U
#
#          Condition  TCG Market Price  TCG Direct Low  \
# 15  Lightly Played              3.95            4.00
# 16  Lightly Played              8.80            8.40
# 29  Lightly Played              2.64            2.50
# 54  Lightly Played              1.82            1.09
# 55  Lightly Played              2.78            1.28
#
#     TCG Low Price With Shipping  TCG Low Price  Buylist Market Price  \
# 15                         4.94           3.95                  2.30
# 16                         8.40           8.40                  5.64
# 29                         3.39           2.40                  1.11
# 54                         1.99           1.00                  1.00
# 55                         1.99           1.00                  1.26
#
#     Buylist High Price
# 15                1.42
# 16                5.22
# 29                0.89
# 54                0.84
# 55                0.94

# %%
filtered.shape
# Out:
# (16859, 12)

# %%
#creating new columns! All of this information is derived, so should maybe be put into functions?
#sellCut and buyCut are defined in cell 2

#Optimistic is buy market, sell market.
#Pessimistic is buy high, sell low
#Emulating high velocity is buy market, sell low
#Buy High Sell Market is when you think not enough people in general are selling something? Unsure why you would use it, but it's here.

filtered['Market-Market'] = filtered['TCG Market Price']*sellCut - filtered['Buylist Market Price']*buyCut
filtered['Market-High'] = filtered['TCG Market Price']*sellCut - filtered['Buylist High Price']*buyCut
filtered['Low-Market'] = filtered['TCG Low Price']*sellCut - filtered['Buylist Market Price']*buyCut
filtered['Low-High'] = filtered['TCG Low Price']*sellCut - filtered['Buylist High Price']*buyCut

# %%
filtered.head()
# Out:
#     TCGplayer Id Product Line           Set Name    Product Name Rarity  \
# 15        363363        Magic  Portal Second Age       Archangel      R
# 16        363364        Magic  Portal Second Age      Armageddon      R
# 29        363377        Magic  Portal Second Age  Coastal Wizard      R
# 54        363402        Magic  Portal Second Age     Goblin Lore      U
# 55        363403        Magic  Portal Second Age   Goblin Matron      U
#
#          Condition  TCG Market Price  TCG Direct Low  \
# 15  Lightly Played              3.95            4.00
# 16  Lightly Played              8.80            8.40
# 29  Lightly Played              2.64            2.50
# 54  Lightly Played              1.82            1.09
# 55  Lightly Played              2.78            1.28
#
#     TCG Low Price With Shipping  TCG Low Price  Buylist Market Price  \
# 15                         4.94           3.95                  2.30
# 16                         8.40           8.40                  5.64
# 29                         3.39           2.40                  1.11
# 54                         1.99           1.00                  1.00
# 55                         1.99           1.00                  1.26
#
#     Buylist High Price  Market-Market  Market-High  Low-Market  Low-High
# 15                1.42         1.4060       2.1980       1.406     2.198
# 16                5.22         2.6680       3.0460       2.316     2.694
# 29                0.89         1.3242       1.5222       1.113     1.311
# 54                0.84         0.7016       0.8456      -0.020     0.124
# 55                0.94         1.3124       1.6004      -0.254     0.034

# %%
#this is kind of a loaded name, but basically it's where the market makes sense. If the market price is lower than the lowest price, the market price is probably wrong.
#at the very least, something is weird, and we don't want to have a computer make a decision about weird things.
rational = filtered.query('(`Buylist High Price` > `Buylist Market Price` and `TCG Market Price` > `TCG Low Price`)')

# %%
rational.head()
# Out:
#      TCGplayer Id Product Line               Set Name           Product Name  \
# 118        363466        Magic      Portal Second Age        Sleight of Hand
# 135        363483        Magic      Portal Second Age  Temporal Manipulation
# 188        363536        Magic           Starter 1999            Devastation
# 283        363631        Magic           Starter 1999           Summer Bloom
# 470        363818        Magic  Portal Three Kingdoms             Zodiac Dog
#
#     Rarity       Condition  TCG Market Price  TCG Direct Low  \
# 118      C  Lightly Played              3.67            4.46
# 135      R  Lightly Played             34.10           27.00
# 188      R  Lightly Played             16.90           15.07
# 283      R  Lightly Played              2.35            1.92
# 470      C  Lightly Played             12.80           12.83
#
#      TCG Low Price With Shipping  TCG Low Price  Buylist Market Price  \
# 118                         4.49           3.50                  1.35
# 135                        26.99          26.00                 18.37
# 188                        15.07          15.07                 11.09
# 283                         2.91           1.92                  0.72
# 470                        11.49          11.49                  5.93
#
#      Buylist High Price  Market-Market  Market-High  Low-Market  Low-High
# 118                1.52         2.0146       1.8616      1.8650    1.7120
# 135               19.34        13.4750      12.6020      6.3470    5.4740
# 188               11.70         4.8910       4.3420      3.2806    2.7316
# 283                0.95         1.4200       1.2130      1.0416    0.8346
# 470                6.21         5.9270       5.6750      4.7742    4.5222

# %%
#How many cards behave the way do we expect, and what is the size of the data set we want to act on?
rational.shape
# Out:
# (2746, 16)

# %%
#And with that, the data is mostly there for you to peruse!

#Some examples!
#if optimistically, we're making less than $1, that's bad!
loss = rational.query('`Market-Market` <= 1')
#if pessimistically, we're making more than $5, that's okay!
win = rational.query('`Low-High` >= 5')

# %%
#How many wins do we have?
win.shape
# Out:
# (189, 16)

# %%
#What are the top wins?
win.sort_values('Market-Market')
win.head()
# Out:
#       TCGplayer Id Product Line           Set Name           Product Name  \
# 135         363483        Magic  Portal Second Age  Temporal Manipulation
# 522         363870        Magic             Portal            Cruel Tutor
# 2850        366220        Magic     Arabian Nights  Island Fish Jasconius
# 2864        366235        Magic     Arabian Nights            Mijae Djinn
# 2880        366251        Magic     Arabian Nights              Shahrazad
#
#      Rarity       Condition  TCG Market Price  TCG Direct Low  \
# 135       R  Lightly Played             34.10           27.00
# 522       R  Lightly Played             29.24           32.85
# 2850      R  Lightly Played             33.88           69.90
# 2864      R  Lightly Played             38.64           39.15
# 2880      R  Lightly Played            432.40          699.00
#
#       TCG Low Price With Shipping  TCG Low Price  Buylist Market Price  \
# 135                         26.99          26.00                 18.37
# 522                         28.49          27.50                 19.28
# 2850                        29.99          29.99                 18.01
# 2864                        38.00          38.00                 22.17
# 2880                       399.98         399.98                286.80
#
#       Buylist High Price  Market-Market  Market-High  Low-Market  Low-High
# 135                19.34        13.4750      12.6020      6.3470    5.4740
# 522                19.38         8.3792       8.2892      6.8480    6.7580
# 2850               18.06        13.6054      13.5604     10.1822   10.1372
# 2864               23.33        14.0502      13.0062     13.4870   12.4430
# 2880              287.02       122.3920     122.1940     93.8624   93.6644

# %%
#How many losses?
loss.shape
# Out:
# (1188, 16)

# %%
loss.sort_values('Low-High')
loss.head()
# Out:
#      TCGplayer Id Product Line Set Name             Product Name Rarity  \
# 534        363882        Magic   Portal               Earthquake      R
# 597        363945        Magic   Portal            Nature's Lore      C
# 688        364036        Magic  Unglued              Bureaucracy      R
# 739        364087        Magic  Unglued  Look at Me, I'm the DCI      R
# 741        364089        Magic  Unglued        Mine, Mine, Mine!      R
#
#           Condition  TCG Market Price  TCG Direct Low  \
# 534  Lightly Played              1.73            1.50
# 597  Lightly Played              1.83            2.73
# 688  Lightly Played              0.84            0.98
# 739  Lightly Played              0.61            0.51
# 741  Lightly Played              0.97            1.23
#
#      TCG Low Price With Shipping  TCG Low Price  Buylist Market Price  \
# 534                         2.61           1.62                  0.62
# 597                         2.32           1.33                  1.01
# 688                         1.65           0.66                  0.28
# 739                         1.49           0.50                  0.16
# 741                         1.87           0.88                  0.31
#
#      Buylist High Price  Market-Market  Market-High  Low-Market  Low-High
# 534                0.71         0.9644       0.8834      0.8676    0.7866
# 597                1.04         0.7014       0.6744      0.2614    0.2344
# 688                0.29         0.4872       0.4782      0.3288    0.3198
# 739                0.18         0.3928       0.3748      0.2960    0.2780
# 741                0.35         0.5746       0.5386      0.4954    0.4594

# %%
#What if we look at all the things that make no sense?
strange = filtered.query('`TCG Market Price` < `TCG Low Price`')
strange.sample(10)
# Out:
#        TCGplayer Id Product Line                        Set Name  \
# 52521       3476488        Magic                Prerelease Cards
# 52077       3468438        Magic                  Iconic Masters
# 23171        838120        Magic                       Guildpact
# 55866       3639534        Magic        World Championship Decks
# 51227       3450122        Magic                  Commander 2017
# 94655       5722567        Magic  Magic Game Night: Free-For-All
# 2337         365706        Magic           Classic Sixth Edition
# 62248       4109921        Magic                   Core Set 2020
# 27663        844705        Magic                Prerelease Cards
# 94224       5702783        Magic             Double Masters 2022
#
#                                    Product Name Rarity            Condition  \
# 52521                          Legion's Landing      R  Lightly Played Foil
# 52077                             Sanguine Bond      U  Lightly Played Foil
# 23171                        Witch-Maw Nephilim      R  Lightly Played Foil
# 55866  Urborg Volcano - 2001 Antoine Ruel (INV)      S       Lightly Played
# 51227                             Mirari's Wake      M       Lightly Played
# 94655                  Vogar, Necropolis Tyrant      M  Lightly Played Foil
# 2337                             Mystical Tutor      U       Lightly Played
# 62248                        Cavalier of Thorns      M  Lightly Played Foil
# 27663                  Ryusei, the Falling Star      P  Lightly Played Foil
# 94224            Force of Negation (Borderless)      R       Lightly Played
#
#        TCG Market Price  TCG Direct Low  TCG Low Price With Shipping  \
# 52521              6.94            9.99                         9.99
# 52077              4.76            4.84                         5.48
# 23171              2.54            5.98                         5.97
# 55866              3.38            4.01                         5.00
# 51227              4.92            4.89                         5.09
# 94655              4.81            5.11                         5.11
# 2337               6.90            7.47                         6.93
# 62248             16.13           14.52                        16.49
# 27663              4.65            4.77                         5.00
# 94224             36.48           39.96                        41.05
#
#        TCG Low Price  Buylist Market Price  Buylist High Price  Market-Market  \
# 52521           9.99                  3.82                3.87         2.6692
# 52077           5.48                  2.37                2.19         2.0558
# 23171           5.97                  2.98                2.82        -0.4468
# 55866           4.01                  0.36                0.45         2.6504
# 51227           5.09                  3.14                2.73         1.5036
# 94655           5.11                  2.66                2.51         1.8388
# 2337            6.93                  6.56                4.72         0.1680
# 62248          16.49                 10.11               10.03         5.0954
# 27663           5.00                  1.87                2.37         2.4090
# 94224          39.96                 24.16               25.26        10.3584
#
#        Market-High  Low-Market  Low-High
# 52521       2.6242      5.3532    5.3082
# 52077       2.2178      2.6894    2.8514
# 23171      -0.3028      2.5716    2.7156
# 55866       2.5694      3.2048    3.1238
# 51227       1.8726      1.6532    2.0222
# 94655       1.9738      2.1028    2.2378
# 2337        1.8240      0.1944    1.8504
# 62248       5.1674      5.4122    5.4842
# 27663       1.9590      2.7170    2.2670
# 94224       9.3684     13.4208   12.4308

# %%
#Looking at all the strange cards in a set
strange.query('`Set Name` == "Dominaria"')
# Out:
#        TCGplayer Id Product Line   Set Name                Product Name  \
# 54724       3613955        Magic  Dominaria       Haphazard Bombardment
# 54782       3614245        Magic  Dominaria           The Eldest Reborn
# 54860       3614635        Magic  Dominaria  Multani, Yavimaya's Avatar
# 54905       3614860        Magic  Dominaria         Karn, Scion of Urza
# 55212       3634087        Magic  Dominaria                Weatherlight
# 55334       3635615        Magic  Dominaria            Cabal Stronghold
# 55719       3637816        Magic  Dominaria                 Shivan Fire
#
#       Rarity            Condition  TCG Market Price  TCG Direct Low  \
# 54724      R  Lightly Played Foil              0.12            0.14
# 54782      U  Lightly Played Foil              8.55            9.87
# 54860      M  Lightly Played Foil              4.69            5.49
# 54905      M       Lightly Played              6.95            8.69
# 55212      M  Lightly Played Foil              4.74            4.24
# 55334      R  Lightly Played Foil              7.22            7.49
# 55719      C  Lightly Played Foil              0.24            0.25
#
#        TCG Low Price With Shipping  TCG Low Price  Buylist Market Price  \
# 54724                         1.13           0.14                  0.01
# 54782                         9.50           9.50                  4.63
# 54860                         5.00           5.00                  2.46
# 54905                         7.05           7.05                  4.58
# 55212                         5.00           5.00                  2.78
# 55334                         7.49           7.49                  3.81
# 55719                         1.24           0.25                  0.01
#
#        Buylist High Price  Market-Market  Market-High  Low-Market  Low-High
# 54724                0.02         0.0966       0.0876      0.1142    0.1052
# 54782                4.90         3.3570       3.1140      4.1930    3.9500
# 54860                2.58         1.9132       1.8052      2.1860    2.0780
# 54905                4.02         1.9940       2.4980      2.0820    2.5860
# 55212                2.30         1.6692       2.1012      1.8980    2.3300
# 55334                4.20         2.9246       2.5736      3.1622    2.8112
# 55719                0.01         0.2022       0.2022      0.2110    0.2110

# %%
#how many things are in our query?
strange.query('`Set Name` == "Dominaria"').shape
# Out:
# (7, 16)

# %%
#What are the cards where the difference is more than 30%, and the market price is more than $1?
strange.query('(abs((`TCG Market Price` / `TCG Low Price`) - 1) > .30) and `TCG Market Price` > 1' )
# Out:
#         TCGplayer Id Product Line                         Set Name  \
# 975           364331        Magic                    Alpha Edition
# 7412          370793        Magic                     Beta Edition
# 7942          371330        Magic                Unlimited Edition
# 17262         405962        Magic                   Oversize Cards
# 19196         830293        Magic                     10th Edition
# ...              ...          ...                              ...
# 100701       6708068        Magic                The Brothers' War
# 100917       6716921        Magic                The Brothers' War
# 103895       6921965        Magic          Secret Lair Drop Series
# 106643       7076211        Magic  Commander: March of the Machine
# 106644       7076236        Magic  Commander: March of the Machine
#
#                             Product Name Rarity            Condition  \
# 975                          Rod of Ruin      U       Lightly Played
# 7412                          Black Vise      U       Lightly Played
# 7942                Vesuvan Doppelganger      R       Lightly Played
# 17262     Glimmervoid Basin (Planechase)      S       Lightly Played
# 19196                    Caves of Koilos      R  Lightly Played Foil
# ...                                  ...    ...                  ...
# 100701                 Cityscape Leveler      M  Lightly Played Foil
# 100917  Cityscape Leveler (Extended Art)      M       Lightly Played
# 103895      Muscle Sliver (Extended Art)      R  Lightly Played Foil
# 106643                 Firemane Commando      R  Lightly Played Foil
# 106644  Firemane Commando (Extended Art)      R       Lightly Played
#
#         TCG Market Price  TCG Direct Low  TCG Low Price With Shipping  \
# 975                54.99           81.98                        80.00
# 7412              107.99          216.19                       194.99
# 7942              113.99          279.94                       200.99
# 17262               2.21            1.90                         5.26
# 19196               4.96            7.95                         7.95
# ...                  ...             ...                          ...
# 100701             17.66           48.86                        33.00
# 100917             18.56           42.82                        28.42
# 103895             10.60           15.68                        19.24
# 106643              1.72            4.29                         4.29
# 106644              1.58            1.99                         3.69
#
#         TCG Low Price  Buylist Market Price  Buylist High Price  \
# 975             80.00                 57.39               23.96
# 7412           190.00                112.81               91.80
# 7942           200.00                120.78              120.83
# 17262            5.26                  0.44                0.20
# 19196            7.95                  8.76                3.00
# ...               ...                   ...                 ...
# 100701          29.00                  8.00                9.94
# 100917          28.42                 11.63               13.03
# 103895          19.24                 14.04                9.50
# 106643           3.30                  0.11                0.68
# 106644           2.70                  0.25                0.73
#
#         Market-Market  Market-High  Low-Market  Low-High
# 975           -3.2598      26.8272     18.7490   48.8360
# 7412          -6.4978      12.4112     65.6710   84.5800
# 7942          -8.3908      -8.4358     67.2980   67.2530
# 17262          1.5488       1.7648      4.2328    4.4488
# 19196         -3.5192       1.6648     -0.8880    4.2960
# ...               ...          ...         ...       ...
# 100701         8.3408       6.5948     18.3200   16.5740
# 100917         5.8658       4.6058     14.5426   13.2826
# 103895        -3.3080       0.7780      4.2952    8.3812
# 106643         1.4146       0.9016      2.8050    2.2920
# 106644         1.1654       0.7334      2.1510    1.7190
#
# [77 rows x 16 columns]

# %%
#Market price on a card is more than 50 cents, but nobody is buylisting it! There might be potential here! (but be careful of buylist fees!)
result.query('`TCG Market Price` > .50 and `Buylist High Price`.isnull()').sort_values('TCG Market Price').tail()
# Out:
#        TCGplayer Id Product Line                            Set Name  \
# 73712       4601468        Magic                     Zendikar Rising
# 30880        850686        Magic         Duel Decks: Venser vs. Koth
# 69994       4456002        Magic                       Core Set 2021
# 67549       4337883        Magic                        Unsanctioned
# 96997       5815748        Magic  Universes Beyond: Warhammer 40,000
#
#                        Product Name Rarity            Condition  \
# 73712                      Mountain      L  Lightly Played Foil
# 30880                 Sawtooth Loon      U       Lightly Played
# 69994  Liliana's Steward (Showcase)      C  Lightly Played Foil
# 67549          Spirit of the Season      U       Lightly Played
# 96997              Dismal Backwater      C       Lightly Played
#
#        TCG Market Price  TCG Direct Low  TCG Low Price With Shipping  \
# 73712              0.90            0.96                         1.74
# 30880              0.99            0.14                         1.13
# 69994              0.99            0.11                         1.04
# 67549              1.17             NaN                         1.12
# 96997              1.99            0.10                         1.15
#
#        TCG Low Price  Buylist Market Price  Buylist High Price
# 73712           0.75                  0.25                 NaN
# 30880           0.14                   NaN                 NaN
# 69994           0.05                  0.01                 NaN
# 67549           0.13                   NaN                 NaN
# 96997           0.16                  0.14                 NaN

# %%
#Among cards that make sense, mid-range LP Foils!
rational.query('(50 > `Low-High` > 10) and `Condition` != "Lightly Played Foil"').sort_values('Low-High').tail()
# Out:
#        TCGplayer Id Product Line                  Set Name  \
# 3566         366947        Magic                   Legends
# 35406       1135463        Magic               Antiquities
# 41777       2837263        Magic       Collector's Edition
# 3765         367146        Magic                    Exodus
# 54907       3615025        Magic  World Championship Decks
#
#                                 Product Name Rarity       Condition  \
# 3566                          Thunder Spirit      R  Lightly Played
# 35406                     Strip Mine (Tower)      U  Lightly Played
# 41777                   Word of Command (CE)      R  Lightly Played
# 3765                        City of Traitors      R  Lightly Played
# 54907  Gaea's Cradle - 1999 Matt Linde (USG)      S  Lightly Played
#
#        TCG Market Price  TCG Direct Low  TCG Low Price With Shipping  \
# 3566             130.33          129.03                       124.99
# 35406            100.39          101.94                        98.85
# 41777             93.43           91.55                        91.54
# 3765             277.31          273.00                       265.99
# 54907            132.13          169.95                       121.96
#
#        TCG Low Price  Buylist Market Price  Buylist High Price  Market-Market  \
# 3566          124.00                 87.56               87.67        35.8864
# 35406          98.85                 58.57               61.18        35.6302
# 41777          91.54                 35.98               42.33        49.8364
# 3765          265.00                201.82              206.41        62.3948
# 54907         121.96                 64.97               66.54        57.8014
#
#        Market-High  Low-Market  Low-High
# 3566       35.7874     30.3160   30.2170
# 35406      33.2812     34.2750   31.9260
# 41777      44.1214     48.1732   42.4582
# 3765       58.2638     51.5620   47.4310
# 54907      56.3884     48.8518   47.4388

# %%
result.shape
# Out:
# (113326, 12)
